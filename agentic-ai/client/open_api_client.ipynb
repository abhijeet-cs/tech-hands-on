# %%
import os
from openai import OpenAI
from dotenv import load_dotenv
from IPython.display import Markdown, display


load_dotenv(override=True)
# Out:
# True

# %%
api_key = os.getenv("GOOGLE_API_KEY")
if not api_key:
    raise ValueError("GOOGLE_API_KEY not set")

# %%
client = OpenAI(
    api_key=api_key,
    base_url="https://generativelanguage.googleapis.com/v1beta/openai/"
)

# %%
messages = [
    {"role": "user", "content": "Hello! Tell me something interesting."}
]

response = client.chat.completions.create(
    model="gemini-3.1-flash-lite-preview",
    messages=messages
)

print(response.choices[0].message.content)
# Out:
# Here is something fascinating that changes how you look at the world around you:
#
# ### **There are more trees on Earth than there are stars in the Milky Way.**
#
# For a long time, people assumed the number of stars in our galaxy was vastly higher than the number of trees on our planet. However, in 2015, a comprehensive study published in the journal *Nature* used satellite imagery and ground-based forest inventories to calculate the global tree count.
#
# They estimated that there are approximately **3.04 trillion trees** on Earth.
#
# In comparison, astronomers estimate there are between **100 billion and 400 billion stars** in the Milky Way galaxy.
#
# **Even taking the most generous estimate for the number of stars, there are still roughly 7 to 10 trees on Earth for every single star in our galaxy.**
#
# ***
#
# **Bonus thought:** If you find that hard to believe, consider this: **Trees are actually relatively "new" in the history of Earth.** For the first 90% of Earth’s history, the land was almost entirely barren of complex plant life. Forests as we know them didn't really start to cover the planet until about 350 to 400 million years ago. Before that, the tallest thing you would find on land was a fungus called *Prototaxites*, which grew up to 26 feet tall—meaning for a long time, the "trees" of Earth were actually giant mushrooms!

# %%
#Markdown
display(Markdown(response.choices[0].message.content))
# Out:
# Here is something fascinating that changes how you look at the world around you:
#
# ### **There are more trees on Earth than there are stars in the Milky Way.**
#
# For a long time, people assumed the number of stars in our galaxy was vastly higher than the number of trees on our planet. However, in 2015, a comprehensive study published in the journal *Nature* used satellite imagery and ground-based forest inventories to calculate the global tree count.
#
# They estimated that there are approximately **3.04 trillion trees** on Earth.
#
# In comparison, astronomers estimate there are between **100 billion and 400 billion stars** in the Milky Way galaxy.
#
# **Even taking the most generous estimate for the number of stars, there are still roughly 7 to 10 trees on Earth for every single star in our galaxy.**
#
# ***
#
# **Bonus thought:** If you find that hard to believe, consider this: **Trees are actually relatively "new" in the history of Earth.** For the first 90% of Earth’s history, the land was almost entirely barren of complex plant life. Forests as we know them didn't really start to cover the planet until about 350 to 400 million years ago. Before that, the tallest thing you would find on land was a fungus called *Prototaxites*, which grew up to 26 feet tall—meaning for a long time, the "trees" of Earth were actually giant mushrooms!
